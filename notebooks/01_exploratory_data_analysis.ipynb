# %% [markdown]
# # Exploratory Data Analysis
#
# This notebook performs exploratory data analysis on the HIGGS dataset.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path().absolute().parent))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.data.loader import load_higgs_data

# %matplotlib inline

# %%
# Load data
data_path = Path('../data/raw/HIGGS.csv.gz')
df = load_higgs_data(str(data_path), n_samples=100000, random_state=42)

print(f"Dataset shape: {df.shape}")
print(f"Features: {df.shape[1] - 1}")
print(f"Samples: {df.shape[0]:,}")
